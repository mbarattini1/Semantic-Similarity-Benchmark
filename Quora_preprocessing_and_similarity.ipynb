# %%
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd ./drive/"My Drive"/"Colab Notebooks"/Quora
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Quora
# /content/drive/My Drive/Colab Notebooks/Quora

# %%
import matplotlib.pyplot as plt
from sklearn import svm
#from sklearn.datasets import make_blobs
#from model_utils import load_model, cos_sim
from Benchmarking.Quora import QuoraData
import pandas as pd
import numpy as np
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, CrossEncoder
tqdm.pandas()

# %% [markdown]
# Load Data

# %%
#Uncomment to load original dataset, preprocess and create train test split
benchmark_models = ['stsb-mpnet-base-v2','all-mpnet-base-v2','stsb-distilroberta-base-v2','all-distilroberta-v1','cross-encoder/stsb-distilroberta-base']
quora = QuoraData(data_loc="data/quora-question-pairs/train.csv",preprocess=True)

for mod in benchmark_models:
  quora.data[mod] = quora.calc_question_similarities(model_name=mod, dataset='data')


quora.create_train_test_split(test_size=0.3)
quora.save_split("data/quora-question-pairs/preprocessed_data")


#Uncomment below to read in already processed/split data
#quora = QuoraData(preprocess= False,
#                  train=pd.read_excel("data/quora-question-pairs/preprocessed_data/train.xlsx"),
#                  test = pd.read_excel("data/quora-question-pairs/preprocessed_data/test.xlsx"))
# Out:
# preprocessing q1
# /content/drive/My Drive/Colab Notebooks/Quora/data_utils.py:46: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 46 of the file /content/drive/My Drive/Colab Notebooks/Quora/data_utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   bfs = BeautifulSoup(x)
# preprocessing q2
# ...
# Batches:   0%|          | 0/12635 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
quora.data.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  \
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0
#
#                               question1_preprocessed  \
# 0  what is the step by step guide to invest in sh...
# ...

# %%
quora.train.head()
# Out:
#             id    qid1    qid2  \
# 27280    27280   50691   50692
# 385176  385176  353405  414169
# 193900  193900  293957  293958
# 129696  129696  208288  208289
# 363109  363109  274005  493065
#
#                                                 question1  \
# 27280      Are team collaboration software user friendly?
# 385176                     Which SBI credit card is best?
# 193900  Has anyone ever won MVP and Defensive Player o...
# 129696                Are nutrilite products over priced?
# 363109  Which one is better computer science or comput...
#
#                                                 question2  is_duplicate  \
# 27280   Is the team collaboration software user friendly?             1
# 385176                  Which credit card of SBI is best?             1
# 193900  Who will be the best player in the NBA in ten ...             0
# 129696  Are Amway nutrilite products worth their price...             0
# ...
